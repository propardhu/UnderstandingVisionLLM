# %%
import torch
from PIL import Image
from transformers import AutoProcessor, AutoModelForVision2Seq

# ✅ Detect device (Use MPS for Mac)
DEVICE = "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Using device: {DEVICE}")

# ✅ Load a single image from local disk (Change file path as needed)
image_path = "./image.jpg"  # Update with your actual path
image = Image.open(image_path).convert("RGB")

# ✅ Initialize processor and model
processor = AutoProcessor.from_pretrained("HuggingFaceTB/SmolVLM-Instruct")
model = AutoModelForVision2Seq.from_pretrained(
    "HuggingFaceTB/SmolVLM-Instruct",
    torch_dtype=torch.float16,  # Use float16 for efficiency on Mac
    attn_implementation="eager",  # Required for Transformers 5.0+
    output_attentions=True,  # Enable attention extraction
    return_dict=True,  # Return output as dictionary
    return_dict_in_generate=True
).to(DEVICE)

print("✅ Model & Processor Loaded!")
# Out:
# Using device: mps
# ✅ Model & Processor Loaded!

# %%
# ✅ Prepare input prompt
messages = [
    {
        "role": "user",
        "content": [
            {"type": "image"},
            {"type": "text", "text": "What is the main subject here?"}
        ]
    },
]

# ✅ Tokenize text prompt
prompt = processor.apply_chat_template(messages, add_generation_prompt=True)

# ✅ Preprocess image and text
inputs = processor(
    text=prompt,
    images=[image],
    return_tensors="pt"
).to(DEVICE)

print("✅ Inputs processed, running inference...")

# ✅ Generate output with attention extraction
with torch.no_grad():
    outputs = model.generate(**inputs, max_new_tokens=500, output_attentions=True, return_dict_in_generate=True)

# ✅ Decode the generated response
generated_texts = processor.batch_decode(outputs.sequences, skip_special_tokens=True)
generated_answer = generated_texts[0]
print("\n📝 **Generated Answer:**")
print("——————————————————————")
print(generated_answer)
print("——————————————————————\n")

# ✅ Extract attentions from model output
attentions = outputs.attentions  # Extract all attention layers
print(f"✅ Extracted {len(attentions)} attention layers.")
# Out:
# ✅ Inputs processed, running inference...
# /opt/anaconda3/lib/python3.12/site-packages/transformers/generation/utils.py:1532: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed in v5. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# 📝 **Generated Answer:**
# ——————————————————————
# User:What is the main subject here?
# Assistant: The main subject of the image is the Statue of Liberty.<row_1_
# ——————————————————————
#
# ✅ Extracted 500 attention layers.

# %%
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import numpy as np

# ✅ Contrast Stretching Function
def contrast_stretch(attn_map):
    p2, p98 = np.percentile(attn_map, (2, 98))  # Get 2nd and 98th percentiles
    attn_map = np.clip((attn_map - p2) / (p98 - p2), 0, 1)  # Stretch contrast
    return attn_map

# ✅ Gamma Correction Function (Enhances Attention Areas)
def gamma_correction(attn_map, gamma=1.5):
    return np.power(attn_map, gamma)

# ✅ Iterate through each decoder layer's attention
for layer_idx, layer_attn in enumerate(attentions):
    print(f"Processing attention map for Layer {layer_idx + 1}, shape {attn_map.shape}")

    if isinstance(layer_attn, tuple):  
        layer_attn = layer_attn[0]  # ✅ Extract the first element if it's a tuple

    # ✅ Average attention across all heads
    attn_map = layer_attn.mean(dim=1).cpu().detach().numpy().squeeze()

    # ✅ Check if attention is 1D & reshape it
    if attn_map.ndim == 1:  
        sqrt_len = int(np.sqrt(attn_map.shape[0]))  # Try to infer the correct 2D shape
        if sqrt_len * sqrt_len == attn_map.shape[0]:
            attn_map = attn_map.reshape(sqrt_len, sqrt_len)  # Reshape to square if possible
        else:
            print(f"⚠️ Skipping Layer {layer_idx + 1}: Non-square attention shape {attn_map.shape}")
            continue  # Skip this layer

    # ✅ Normalize the attention map safely
    attn_map = (attn_map - attn_map.min()) / (attn_map.max() - attn_map.min() + 1e-8)  # Avoid division by zero

    # ✅ Apply Contrast Stretching & Gamma Correction
    attn_map = contrast_stretch(attn_map)
    attn_map = gamma_correction(attn_map, gamma=1.7)  # More contrast

    # ✅ Convert to Torch Tensor and add batch dimension
    attn_map_tensor = torch.tensor(attn_map).unsqueeze(0).unsqueeze(0)  # Shape (1,1,H,W)

    # ✅ Resize attention map to match image dimensions
    resize_transform = transforms.Resize((image.height, image.width), antialias=True)
    attn_map_resized = resize_transform(attn_map_tensor).squeeze().numpy()

    # ✅ Plot the Original Image & Attention Map
    plt.figure(figsize=(12, 6))

    # 🔹 Original Image
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.axis("off")
    plt.title("Original Image")

    # 🔹 Attention Heatmap
    plt.subplot(1, 2, 2)
    plt.imshow(image)
    plt.imshow(attn_map_resized, cmap="inferno", alpha=0.5)
    plt.axis("off")
    plt.title(f"Attention Heatmap - Layer {layer_idx+1}")

    # ✅ Save each heatmap separately
    heatmap_filename = f"attention_layer_{layer_idx+1}.png"
    plt.savefig(heatmap_filename, dpi=300)
    print(f"✅ Saved heatmap: {heatmap_filename}")

plt.show()
# Out:
# Processing attention map for Layer 1
# ✅ Saved heatmap: attention_layer_1.png
# Processing attention map for Layer 2
# ⚠️ Skipping Layer 2: Non-square attention shape (1199,)
# Processing attention map for Layer 3
# ⚠️ Skipping Layer 3: Non-square attention shape (1200,)
# Processing attention map for Layer 4
# ⚠️ Skipping Layer 4: Non-square attention shape (1201,)
# Processing attention map for Layer 5
# ⚠️ Skipping Layer 5: Non-square attention shape (1202,)
# Processing attention map for Layer 6
# ⚠️ Skipping Layer 6: Non-square attention shape (1203,)
# Processing attention map for Layer 7
# ⚠️ Skipping Layer 7: Non-square attention shape (1204,)
# Processing attention map for Layer 8
# ⚠️ Skipping Layer 8: Non-square attention shape (1205,)
# Processing attention map for Layer 9
# ⚠️ Skipping Layer 9: Non-square attention shape (1206,)
# Processing attention map for Layer 10
# ⚠️ Skipping Layer 10: Non-square attention shape (1207,)
# Processing attention map for Layer 11
# ...

# %%
model
# Out:
# Idefics3ForConditionalGeneration(
#   (model): Idefics3Model(
#     (vision_model): Idefics3VisionTransformer(
#       (embeddings): Idefics3VisionEmbeddings(
#         (patch_embedding): Conv2d(3, 1152, kernel_size=(14, 14), stride=(14, 14), padding=valid)
#         (position_embedding): Embedding(729, 1152)
#       )
#       (encoder): Idefics3Encoder(
#         (layers): ModuleList(
#           (0-26): 27 x Idefics3EncoderLayer(
#             (self_attn): Idefics3VisionAttention(
#               (k_proj): Linear(in_features=1152, out_features=1152, bias=True)
#               (v_proj): Linear(in_features=1152, out_features=1152, bias=True)
#               (q_proj): Linear(in_features=1152, out_features=1152, bias=True)
#               (out_proj): Linear(in_features=1152, out_features=1152, bias=True)
#             )
#             (layer_norm1): LayerNorm((1152,), eps=1e-06, elementwise_affine=True)
#             (mlp): Idefics3VisionMLP(
# ...

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model.summary()
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1935, in Module.__getattr__(self, name)
#    1933     if name in modules:
#    1934         return modules[name]
# -> 1935 raise AttributeError(
#    1936     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1937 )
#
# AttributeError: 'Idefics3ForConditionalGeneration' object has no attribute 'summary'
